# %% [markdown]
# <a href="https://colab.research.google.com/github/RohanNaseem0341/Data-Analysis-by-Python/blob/main/Python_libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file.memory_usage(deep=True)
# Out:
# Index         128
# name      1589957
# sex       1455916
# births     200816
# year       200816
# dtype: int64

# %%
import pandas as pd
file=pd.read_csv("drive/MyDrive/csvFiles/yob1991.csv")
print(file.columns)
# Out:
# Index(['name', 'sex', 'births', 'year'], dtype='object')

# %%
import pandas as pd
file=pd.read_csv("drive/MyDrive/csvFiles/yob1991.csv")
file
# Out:
#            name sex  births  year
# 0        Ashley   F   43482  1991
# 1       Jessica   F   43396  1991
# 2      Brittany   F   29091  1991
# 3        Amanda   F   28884  1991
# 4      Samantha   F   25648  1991
# ...         ...  ..     ...   ...
# 25097      Zeev   M       5  1991
# 25098      Zein   M       5  1991
# 25099    Zerick   M       5  1991
# 25100    Zeshan   M       5  1991
# 25101    Zuhair   M       5  1991
#
# [25102 rows x 4 columns]

# %%
from matplotlib import pyplot as plt
_df_0['index'].plot(kind='hist', bins=20, title='index')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
print(file.shape)
# Out:
# (25102, 4)

# %%
from os import name
file.sort_values(['name','year'],ascending=True)
# Out:
#           name sex  births  year
# 9332    Aaisha   F       8  1991
# 19684   Aakash   M      13  1991
# 5944   Aaliyah   F      15  1991
# 11508   Aamber   F       6  1991
# 13139  Aaminah   F       5  1991
# ...        ...  ..     ...   ...
# 21398   Zuriel   M       9  1991
# 15460     Zury   F       5  1991
# 10272  Zuzanna   F       8  1991
# 22725      Zvi   M       7  1991
# 11507    Zykia   F       7  1991
#
# [25102 rows x 4 columns]

# %%
data_com=file[['name',' year']]
print(data_com.head(5))
# Out:
#        name  year
# 0    Ashley  1991
# 1   Jessica  1991
# 2  Brittany  1991
# 3    Amanda  1991
# 4  Samantha  1991

# %%
print(file.head)
# Out:
# <bound method NDFrame.head of            name sex  births  year
# 0        Ashley   F   43482  1991
# 1       Jessica   F   43396  1991
# 2      Brittany   F   29091  1991
# 3        Amanda   F   28884  1991
# 4      Samantha   F   25648  1991
# ...         ...  ..     ...   ...
# 25097      Zeev   M       5  1991
# 25098      Zein   M       5  1991
# 25099    Zerick   M       5  1991
# 25100    Zeshan   M       5  1991
# 25101    Zuhair   M       5  1991
#
# [25102 rows x 4 columns]>

# %%
data_analyse= file[file['sex']=='F']
print(file['sex']=='F')
data_analyse
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 25097    False
# 25098    False
# 25099    False
# 25100    False
# 25101    False
# Name: sex, Length: 25102, dtype: bool
#            name sex  births  year
# 0        Ashley   F   43482  1991
# 1       Jessica   F   43396  1991
# 2      Brittany   F   29091  1991
# 3        Amanda   F   28884  1991
# 4      Samantha   F   25648  1991
# ...         ...  ..     ...   ...
# 15456     Zofia   F       5  1991
# 15457   Zorayda   F       5  1991
# 15458     Zuhal   F       5  1991
# 15459     Zulay   F       5  1991
# 15460      Zury   F       5  1991
#
# [15461 rows x 4 columns]

# %%
data_analyse= file[(file['sex']=='F')& (file['name']=='Ashely')]
data_analyse
# Out:
#        name sex  births  year
# 676  Ashely   F     316  1991

# %%
file['code']=file['sex']+file['name']
print(file.head(4))
#concatenation make two column combine
# Out:
#        name sex  births  year       code
# 0    Ashley   F   43482  1991    FAshley
# 1   Jessica   F   43396  1991   FJessica
# 2  Brittany   F   29091  1991  FBrittany
# 3    Amanda   F   28884  1991    FAmanda

# %%
file['births'].mean()
# Out:
# 155.0923432395825

# %%
file[['births','year']].median()
# Out:
# births      11.0
# year      1991.0
# dtype: float64

# %%
file[['births','year']].describe()
# Out:
#              births     year
# count  25102.000000  25102.0
# mean     155.092343   1991.0
# std     1335.230394      0.0
# min        5.000000   1991.0
# 25%        6.000000   1991.0
# 50%       11.000000   1991.0
# 75%       28.000000   1991.0
# max    60780.000000   1991.0

# %%
file[['births','year']].agg(['min','max','mean'])
# Out:
#             births    year
# min       5.000000  1991.0
# max   60780.000000  1991.0
# mean    155.092343  1991.0

# %%
print(file.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25102 entries, 0 to 25101
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    25102 non-null  object
#  1   sex     25102 non-null  object
#  2   births  25102 non-null  int64
#  3   year    25102 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 784.6+ KB
# None

# %%
import pandas as pd


data={'names':['Rohan','Ammar'],'Age':[20,23],'Class':['XI','XII']}
pd.DataFrame(data,index=[1,2])
# Out:
# 3    1
# 4    2
# 5    3
# Name: Product A, dtype: int64

# %%
sale=pd.Series([1,2,3],index=[3,4,5],name='Product A')
print(sale)

# %%
sale.to_frame()
# Out:
#    Product A
# 3          1
# 4          2
# 5          3

# %%
print(file.value_counts)
# Out:
# <bound method DataFrame.value_counts of            name sex  births  year
# 0        Ashley   F   43482  1991
# 1       Jessica   F   43396  1991
# 2      Brittany   F   29091  1991
# 3        Amanda   F   28884  1991
# 4      Samantha   F   25648  1991
# ...         ...  ..     ...   ...
# 25097      Zeev   M       5  1991
# 25098      Zein   M       5  1991
# 25099    Zerick   M       5  1991
# 25100    Zeshan   M       5  1991
# 25101    Zuhair   M       5  1991
#
# [25102 rows x 4 columns]>

# %%
file.sex.value_counts()
# Out:
# F    15461
# M     9641
# Name: sex, dtype: int64

# %%
file.name.value_counts()
# Out:
# Ashley       2
# Spencer      2
# Isa          2
# Khanh        2
# Hien         2
#             ..
# Shayda       1
# Shawnetta    1
# Shawnell     1
# Shavanna     1
# Zuhair       1
# Name: name, Length: 23073, dtype: int64

# %%
file.sex.value_counts(normalize=True)
# Out:
# F    0.615927
# M    0.384073
# Name: sex, dtype: float64

# %%
print(file.columns)
# Out:
# Index(['name', 'sex', 'births', 'year'], dtype='object')

# %%
print(file.index)
# Out:
# RangeIndex(start=0, stop=25102, step=1)

# %%
file.sort_values('year',ascending=False)
# Out:
#            name sex  births  year
# 0        Ashley   F   43482  1991
# 16742      Dirk   M      76  1991
# 16740    Turner   M      77  1991
# 16739       Tou   M      77  1991
# 16738    Stefon   M      77  1991
# ...         ...  ..     ...   ...
# 8365    Marybel   F      10  1991
# 8364    Marteka   F      10  1991
# 8363   Marquisa   F      10  1991
# 8362    Marline   F      10  1991
# 25101    Zuhair   M       5  1991
#
# [25102 rows x 4 columns]
